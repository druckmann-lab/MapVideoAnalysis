# %% [markdown]
# # Figure 2
#
# Showing explained variance across different methods and regions.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pickle
from scipy import stats

import local_env
import VideoAnalysisUtils.functions as func
import VideoAnalysisUtils.plotting_utils as plt_utils
import VideoAnalysisUtils.plot_style as style
# Out:
# /home/kurgyis/Research/MapVideoAnalysis/python38_venv/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
figfolder = '../figs/manuscript_drafts/'
os.makedirs(figfolder, exist_ok=True)

# %%
fig2 = plt_utils.Figure2()
fig2.load_data(combined_r2_file = 'combined_methods_r2_new.pickle')

# %% [markdown]
# ## Main figure

# %%
fig2.plot_fig2_main()
# Out:
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Midbrain (0.11729667785845017 +/- 0.001897926301445882 ): U = 2445963.0, p = 1.1521816393046025e-58
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1464199.0, p = 9.304272491926692e-97
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1712045.0, p = 1.3693552262303428e-89
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3105731.0, p = 2.3800143715906125e-274
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1696766.0, p = 1.3380698039518291e-18
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1942032.0, p = 1.353015975320634e-10
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3834899.0, p = 5.450655333710907e-145
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 867708.0, p = 0.004205570969616735
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 1818579.0, p = 2.083684689398102e-40
# Striatum (0.09856986196912691 +/- 0.0020909881365335434) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 2300723.0, p = 1.8488629966550733e-69
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79: U = 2604.0, p = 1.0351574224161924e-11
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 2638.0, p = 1.23767777209654e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2325.0, p = 1.0252410994926085e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 2224.0, p = 3.309058408967697e-15
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 3649.0, p = 0.3142534025380551
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 3303.0, p = 0.09988381235478641
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 4136.0, p = 2.465518125623638e-11
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2583.0, p = 9.90413176669508
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3790.0, p = 2.8026083849255445e-08
# Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3380.0, p = 8.255775829955578e-09
# (<Figure size 2124x2478 with 10 Axes>,
#  [<Axes: title={'center': 'Response epoch explained variance'}, xlabel='Anterior-Posterior', ylabel='Dorsal-Ventral'>,
#   <Axes: ylabel='Mean explained variance'>,
#   <Axes: xlabel='Marker explained variance', ylabel='Embedding explained variance'>,
#   <Axes: xlabel='Marker explained variance', ylabel='End-to-end explained variance'>,
#   <Axes: xlabel='Embedding explained variance', ylabel='End-to-end explained variance'>,
#   <Axes: xlabel='Time (s)', ylabel='Spike rate (Hz)'>,
#   <Axes: xlabel='Time (s)', ylabel='Spike rate (Hz)'>,
#   <Axes: xlabel='Time (s)', ylabel='Spike rate (Hz)'>,
#   <Axes: xlabel='Time (s)', ylabel='Spike rate (Hz)'>])

# %%
f,ax = plt.subplots(1,1, figsize=(3.5, 3))
fig2.plot_barplot_with_sem(ax = ax, ylim = [0,0.333], legend_anchor=[0.65,0.75])
_,_,_,ps = fig2.get_barplot_statistics(epoch = 'response')
fig2._statistics_decorator_from_p_values(ax,ps, x_init = 0.3325, fonts = 5,)
# Out:
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Midbrain (0.11729667785845017 +/- 0.001897926301445882 ): U = 2445963.0, p = 1.1521816393046025e-58
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1464199.0, p = 9.304272491926692e-97
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1712045.0, p = 1.3693552262303428e-89
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3105731.0, p = 2.3800143715906125e-274
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1696766.0, p = 1.3380698039518291e-18
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1942032.0, p = 1.353015975320634e-10
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3834899.0, p = 5.450655333710907e-145
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 867708.0, p = 0.004205570969616735
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 1818579.0, p = 2.083684689398102e-40
# Striatum (0.09856986196912691 +/- 0.0020909881365335434) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 2300723.0, p = 1.8488629966550733e-69
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79: U = 2604.0, p = 1.0351574224161924e-11
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 2638.0, p = 1.23767777209654e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2325.0, p = 1.0252410994926085e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 2224.0, p = 3.309058408967697e-15
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 3649.0, p = 0.3142534025380551
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 3303.0, p = 0.09988381235478641
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 4136.0, p = 2.465518125623638e-11
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2583.0, p = 9.90413176669508
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3790.0, p = 2.8026083849255445e-08
# Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3380.0, p = 8.255775829955578e-09
# <Axes: ylabel='Mean explained variance'>

# %%
_=fig2.plot_fig2_main_final()
plt.savefig(figfolder + 'main_fig2.pdf', dpi=300, bbox_inches='tight')
# Out:
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Midbrain (0.11729667785845017 +/- 0.001897926301445882 ): U = 2445963.0, p = 1.1521816393046025e-58
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1464199.0, p = 9.304272491926692e-97
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1712045.0, p = 1.3693552262303428e-89
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3105731.0, p = 2.3800143715906125e-274
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1696766.0, p = 1.3380698039518291e-18
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1942032.0, p = 1.353015975320634e-10
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3834899.0, p = 5.450655333710907e-145
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 867708.0, p = 0.004205570969616735
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 1818579.0, p = 2.083684689398102e-40
# Striatum (0.09856986196912691 +/- 0.0020909881365335434) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 2300723.0, p = 1.8488629966550733e-69
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79: U = 2604.0, p = 1.0351574224161924e-11
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 2638.0, p = 1.23767777209654e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2325.0, p = 1.0252410994926085e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 2224.0, p = 3.309058408967697e-15
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 3649.0, p = 0.3142534025380551
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 3303.0, p = 0.09988381235478641
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 4136.0, p = 2.465518125623638e-11
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2583.0, p = 9.90413176669508
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3790.0, p = 2.8026083849255445e-08
# Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3380.0, p = 8.255775829955578e-09

# %%
fig2.get_method_comparison_stats()
# Out:
# Number of neurons: 12312
# marker vs embed: improvement = 1.7436265850139054 +/- 0.06621651817407823, n = 105 sessions, p = 8.753152108850619e-19
# marker vs e2e: improvement = 3.7677560595019686 +/- 0.11475421595209041, n = 105 sessions, p = 8.753152108850619e-19
# embed vs e2e: improvement = 0.8301976354672864 +/- 0.03115131595700766, n = 105 sessions, p = 9.271705817454345e-19

# %% [markdown]
# ## Supplementary figures

# %%
f,axs = plt.subplots(1,3, figsize=(7.8,2.4))
axs = axs.flatten()
#f.suptitle('No FR filter')
fig2.plot_saggital_heatmap(fig = f, ax = axs[0], epoch = 'response', title_str='Response epoch explained variance', cbar_fraction= 0.06, r2_threshold=0.005,cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, vlims=[0,0.15], voxel_size=150, filter_size=3, cbar_label= 'Explained variance', use_all_sessions=True, colormap='Blues')

fig2.plot_saggital_heatmap(fig = f, ax = axs[1], epoch = 'sample_delay', title_str= 'Sample+Delay epoch avg. explained variance', cbar_fraction= 0.06,r2_threshold=0.005, cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, vlims=[0,0.15], voxel_size=150, filter_size=3, cbar_label= 'Explained variance', use_all_sessions=True, colormap='Blues')

fig2.plot_saggital_heatmap(fig = f, ax = axs[2], epoch = 'response-sample_delay', title_str= 'Between epoch difference', cbar_fraction= 0.06,r2_threshold=0,fr_threshold=2, cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, vlims=[-0.1,0.1], voxel_size=150, filter_size=3, cbar_label= 'Explained variance difference', use_all_sessions=True, colormap='bwr')

#plt.savefig('../figs/supplementary_figs/between_epoch_heatmap_differences.pdf', dpi=300, bbox_inches = 'tight')

# %%
f, axs = plt.subplots(3,3, figsize=(7.8,9))
f.subplots_adjust(wspace=0.15,)
axs = axs.flatten()

fig2.plot_saggital_heatmap(fig = f, ax = axs[0], epoch = 'response', 
                           title_str='Response epoch explained variance', 
                           cbar_fraction= 0.06, r2_threshold=0.005,
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')

fig2.plot_saggital_heatmap(fig = f, ax = axs[1], epoch = 'sample_delay', 
                           title_str= 'Sample+Delay epoch avg. explained variance', 
                           cbar_fraction= 0.06,r2_threshold=0.005, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')

fig2.plot_saggital_heatmap(fig = f, ax = axs[2], epoch = 'response-sample_delay', 
                           title_str= 'Between epoch difference', 
                           cbar_fraction= 0.06,r2_threshold=0,fr_threshold=2, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[-0.1,0.1], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance difference', 
                           use_all_sessions=True, colormap='bwr')

coronal_shift = 0.035

fig2.plot_coronal_heatmap(fig = f, ax = axs[3], epoch = 'response', 
                           title_str='Response epoch explained variance', 
                           cbar_fraction= 0.06, r2_threshold=0.005,
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.035, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')

fig2.plot_coronal_heatmap(fig = f, ax = axs[4], epoch = 'sample_delay', 
                           title_str= 'Sample+Delay epoch avg. explained variance', 
                           cbar_fraction= 0.06,r2_threshold=0.005, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.035, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')

fig2.plot_coronal_heatmap(fig = f, ax = axs[5], epoch = 'response-sample_delay', 
                           title_str= 'Between epoch difference', 
                           cbar_fraction= 0.06,r2_threshold=0,fr_threshold=2, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.035, 
                           vlims=[-0.1,0.1], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance difference', 
                           use_all_sessions=True, colormap='bwr')

for ii in range(3,6):
    pos = axs[ii].get_position()
    axs[ii].set_position([pos.x0, pos.y0+coronal_shift, pos.width, pos.height])

fig2.plot_horizontal_heatmap(fig = f, ax = axs[6], epoch = 'response', 
                           title_str='Response epoch explained variance', 
                           cbar_fraction= 0.06, r2_threshold=0.005,
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')
pos = axs[6].get_position()
axs[6].set_position([pos.x0, pos.y0, pos.width, pos.height*2])

fig2.plot_horizontal_heatmap(fig = f, ax = axs[7], epoch = 'sample_delay', 
                           title_str= 'Sample+Delay epoch avg. explained variance', 
                           cbar_fraction= 0.06,r2_threshold=0.005, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[0,0.15], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance', 
                           use_all_sessions=True, colormap='Blues')

pos = axs[7].get_position()
axs[7].set_position([pos.x0, pos.y0, pos.width, pos.height*2])

fig2.plot_horizontal_heatmap(fig = f, ax = axs[8], epoch = 'response-sample_delay', 
                           title_str= 'Between epoch difference', 
                           cbar_fraction= 0.06,r2_threshold=0,fr_threshold=2, 
                           cbar_x0_shift=-0.0, cbar_y0_shift = 0.0, 
                           vlims=[-0.1,0.1], voxel_size=150, filter_size=3, 
                           cbar_label= 'Explained variance difference', 
                           use_all_sessions=True, colormap='bwr')
pos = axs[8].get_position()
axs[8].set_position([pos.x0, pos.y0, pos.width, pos.height*2])

plt.savefig('../figs/supplementary_figs/between_epoch_heatmap_differences_all.jpg', dpi=300, bbox_inches = 'tight')
plt.show()
plt.close()

# %%
fig, axs = plt.subplots(1,3, figsize=(7.08,2.4))
fig.subplots_adjust(wspace=0.4)
axs = axs.flatten()
epochs = ['sample', 'delay', 'response']

for i, epoch in enumerate(epochs):
    _,_,_,ps = fig2.get_barplot_statistics(epoch = epoch)
    fig2.plot_barplot_with_sem(axs[i], fr_threshold = 2, r2_threshold = 0.01, 
                               fr_filter='epoch', epoch = epoch, 
                               ylim = [0,0.338], legend_anchor=[0.65,0.75-0.05*(i==0)],
                               label_names = ['Embedding', 'Marker', 'End-to-end'])
    axs[i].set_ylabel('%s epoch explained variance'%epoch)
    axs[i].set_title('%s epoch'%epoch)
    fig2._statistics_decorator_from_p_values(axs[i],ps, x_init = 0.336, fonts = 5)

plt.savefig('../figs/supplementary_figs/'+ 'all_epochs_explained_variance_by_area.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# Medulla (0.08676062440188978 +/- 0.0026017768199179756) vs Midbrain (0.07293599969151096 +/- 0.002113890914653389 ): U = 552748.0, p = 3.3292636587995145e-07
# Medulla (0.08676062440188978 +/- 0.0026017768199179756) vs ALM (0.06764033213320067 +/- 0.0028143144648143732 ): U = 291652.0, p = 1.663277674028329e-09
# Medulla (0.08676062440188978 +/- 0.0026017768199179756) vs Striatum (0.06511170577962558 +/- 0.0029073717686815275 ): U = 262180.0, p = 2.2546563443162905e-10
# Medulla (0.08676062440188978 +/- 0.0026017768199179756) vs Thalamus (0.03957683754856288 +/- 0.0013394567541118285 ): U = 520351.0, p = 7.528526077770236e-64
# Midbrain (0.07293599969151096 +/- 0.002113890914653389) vs ALM (0.06764033213320067 +/- 0.0028143144648143732 ): U = 332040.0, p = 0.0391767142906268
# Midbrain (0.07293599969151096 +/- 0.002113890914653389) vs Striatum (0.06511170577962558 +/- 0.0029073717686815275 ): U = 298119.0, p = 0.014770956087365724
# Midbrain (0.07293599969151096 +/- 0.002113890914653389) vs Thalamus (0.03957683754856288 +/- 0.0013394567541118285 ): U = 612533.0, p = 3.9078486333539563e-42
# ALM (0.06764033213320067 +/- 0.0028143144648143732) vs Striatum (0.06511170577962558 +/- 0.0029073717686815275 ): U = 140574.0, p = 0.8143174441379138
# ALM (0.06764033213320067 +/- 0.0028143144648143732) vs Thalamus (0.03957683754856288 +/- 0.0013394567541118285 ): U = 293903.0, p = 3.516418997298199e-21
# Striatum (0.06511170577962558 +/- 0.0029073717686815275) vs Thalamus (0.03957683754856288 +/- 0.0013394567541118285 ): U = 260595.0, p = 6.242273625097992e-20
# Medulla (0.08326919232528068 +/- 0.006599173233673323) n = 36 vs Midbrain (0.06322054638221873 +/- 0.0038805509160105586) n = 70: U = 1659.0, p = 0.07850343216059784
# Medulla (0.08326919232528068 +/- 0.006599173233673323) n = 36 vs ALM (0.06287145166779383 +/- 0.004654205524397156) n = 69: U = 1671.0, p = 0.03818704025940309
# Medulla (0.08326919232528068 +/- 0.006599173233673323) n = 36 vs Striatum (0.05858010634082144 +/- 0.004616206885467317) n = 59: U = 1463.0, p = 0.021233231345603645
# Medulla (0.08326919232528068 +/- 0.006599173233673323) n = 36 vs Thalamus (0.03643828344418685 +/- 0.0027113278274290323) n = 57: U = 1724.0, p = 3.7654350471465267e-07
# Midbrain (0.06322054638221873 +/- 0.0038805509160105586) n = 70 vs ALM (0.06287145166779383 +/- 0.004654205524397156) n = 69: U = 2533.0, p = 6.206116194478353
# Midbrain (0.06322054638221873 +/- 0.0038805509160105586) n = 70 vs Striatum (0.05858010634082144 +/- 0.004616206885467317) n = 59: U = 2292.0, p = 2.842551921781342
# Midbrain (0.06322054638221873 +/- 0.0038805509160105586) n = 70 vs Thalamus (0.03643828344418685 +/- 0.0027113278274290323) n = 57: U = 3047.0, p = 3.452102177199683e-06
# ALM (0.06287145166779383 +/- 0.004654205524397156) n = 69 vs Striatum (0.05858010634082144 +/- 0.004616206885467317) n = 59: U = 2165.0, p = 5.374691752998462
# ALM (0.06287145166779383 +/- 0.004654205524397156) n = 69 vs Thalamus (0.03643828344418685 +/- 0.0027113278274290323) n = 57: U = 2833.0, p = 0.00021890819849116602
# Striatum (0.05858010634082144 +/- 0.004616206885467317) n = 59 vs Thalamus (0.03643828344418685 +/- 0.0027113278274290323) n = 57: U = 2344.0, p = 0.002562985785647511
# Medulla (0.0939632609098379 +/- 0.002826227635693543) vs Midbrain (0.08373174011815394 +/- 0.0024524668171517243 ): U = 582515.0, p = 0.00016928775200724527
# Medulla (0.0939632609098379 +/- 0.002826227635693543) vs ALM (0.06574950594302793 +/- 0.0028612721120242425 ): U = 343849.0, p = 9.721990152528214e-17
# Medulla (0.0939632609098379 +/- 0.002826227635693543) vs Striatum (0.06737182825071758 +/- 0.0029355860290679295 ): U = 265482.0, p = 7.899870672080935e-11
# Medulla (0.0939632609098379 +/- 0.002826227635693543) vs Thalamus (0.04783416745010104 +/- 0.0017785015495887424 ): U = 599310.0, p = 2.4541524795336106e-58
# Midbrain (0.08373174011815394 +/- 0.0024524668171517243) vs ALM (0.06574950594302793 +/- 0.0028612721120242425 ): U = 395213.0, p = 3.4764976371239095e-08
# Midbrain (0.08373174011815394 +/- 0.0024524668171517243) vs Striatum (0.06737182825071758 +/- 0.0029355860290679295 ): U = 303780.0, p = 0.00016483147927088298
# Midbrain (0.08373174011815394 +/- 0.0024524668171517243) vs Thalamus (0.04783416745010104 +/- 0.0017785015495887424 ): U = 705555.0, p = 2.98182123985462e-45
# ALM (0.06574950594302793 +/- 0.0028612721120242425) vs Striatum (0.06737182825071758 +/- 0.0029355860290679295 ): U = 134065.0, p = 0.2159824115623391
# ALM (0.06574950594302793 +/- 0.0028612721120242425) vs Thalamus (0.04783416745010104 +/- 0.0017785015495887424 ): U = 324132.0, p = 3.8638744039553886e-12
# Striatum (0.06737182825071758 +/- 0.0029355860290679295) vs Thalamus (0.04783416745010104 +/- 0.0017785015495887424 ): U = 266699.0, p = 2.3268357842237374e-14
# Medulla (0.09270928244123962 +/- 0.006522193918039578) n = 36 vs Midbrain (0.06903397192637628 +/- 0.004476661189443026) n = 67: U = 1635.0, p = 0.030395174045358846
# Medulla (0.09270928244123962 +/- 0.006522193918039578) n = 36 vs ALM (0.06537604275880655 +/- 0.006855623373488163) n = 70: U = 1857.0, p = 0.0006911253836554172
# Medulla (0.09270928244123962 +/- 0.006522193918039578) n = 36 vs Striatum (0.05936374959804351 +/- 0.006284924041650306) n = 57: U = 1570.0, p = 0.00018123037847970065
# Medulla (0.09270928244123962 +/- 0.006522193918039578) n = 36 vs Thalamus (0.03465639832571043 +/- 0.002799694154215712) n = 53: U = 1732.0, p = 8.058232958245012e-10
# Midbrain (0.06903397192637628 +/- 0.004476661189443026) n = 67 vs ALM (0.06537604275880655 +/- 0.006855623373488163) n = 70: U = 2703.0, p = 1.2371599483040132
# Midbrain (0.06903397192637628 +/- 0.004476661189443026) n = 67 vs Striatum (0.05936374959804351 +/- 0.006284924041650306) n = 57: U = 2370.0, p = 0.21093038956033133
# Midbrain (0.06903397192637628 +/- 0.004476661189443026) n = 67 vs Thalamus (0.03465639832571043 +/- 0.002799694154215712) n = 53: U = 2856.0, p = 1.1464375350409483e-07
# ALM (0.06537604275880655 +/- 0.006855623373488163) n = 70 vs Striatum (0.05936374959804351 +/- 0.006284924041650306) n = 57: U = 2184.0, p = 3.608668519339205
# ALM (0.06537604275880655 +/- 0.006855623373488163) n = 70 vs Thalamus (0.03465639832571043 +/- 0.002799694154215712) n = 53: U = 2756.0, p = 4.242404999467612e-05
# Striatum (0.05936374959804351 +/- 0.006284924041650306) n = 57 vs Thalamus (0.03465639832571043 +/- 0.002799694154215712) n = 53: U = 2075.0, p = 0.007410988670461788
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Midbrain (0.11729667785845017 +/- 0.001897926301445882 ): U = 2445963.0, p = 1.1521816393046025e-58
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1464199.0, p = 9.304272491926692e-97
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1712045.0, p = 1.3693552262303428e-89
# Medulla (0.18202797255336123 +/- 0.0033998229805590804) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3105731.0, p = 2.3800143715906125e-274
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs ALM (0.09399712792495576 +/- 0.002286605618074609 ): U = 1696766.0, p = 1.3380698039518291e-18
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 1942032.0, p = 1.353015975320634e-10
# Midbrain (0.11729667785845017 +/- 0.001897926301445882) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 3834899.0, p = 5.450655333710907e-145
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Striatum (0.09856986196912691 +/- 0.0020909881365335434 ): U = 867708.0, p = 0.004205570969616735
# ALM (0.09399712792495576 +/- 0.002286605618074609) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 1818579.0, p = 2.083684689398102e-40
# Striatum (0.09856986196912691 +/- 0.0020909881365335434) vs Thalamus (0.0634624196812445 +/- 0.0011662182503390502 ): U = 2300723.0, p = 1.8488629966550733e-69
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79: U = 2604.0, p = 1.0351574224161924e-11
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 2638.0, p = 1.23767777209654e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2325.0, p = 1.0252410994926085e-13
# Medulla (0.17637308889981604 +/- 0.006134232013221692) n = 36 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 2224.0, p = 3.309058408967697e-15
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77: U = 3649.0, p = 0.3142534025380551
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 3303.0, p = 0.09988381235478641
# Midbrain (0.10425045026796557 +/- 0.003952714711709943) n = 79 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 4136.0, p = 2.465518125623638e-11
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67: U = 2583.0, p = 9.90413176669508
# ALM (0.0923406678804272 +/- 0.0036898328329322944) n = 77 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3790.0, p = 2.8026083849255445e-08
# Striatum (0.09124806869608708 +/- 0.0033959912662631284) n = 67 vs Thalamus (0.06114383049699204 +/- 0.0026102445099539296) n = 62: U = 3380.0, p = 8.255775829955578e-09

# %%
len(ps)
# Out:
# 10

# %%
p_array = np.zeros((5,5))
p_array[0,1:5] = ps[0:4]
p_array[1,2:5] = ps[4:7]
p_array[2,3:5] = ps[7:9]
p_array[3,4] = ps[9]

p_array += p_array.T

p_array += np.eye(5)  # Avoid log(0) issues

# %%
from matplotlib.colors import LogNorm

plt.imshow(p_array, cmap='gray_r', norm=LogNorm(vmin=1e-8, vmax=1))
plt.colorbar(label='p-value')

# %% [markdown]
# ## Single animal plots
#
# Reviewer asked about single-animal breakdown. so here we go.

# %%
reviewer_folder = '../figs/reviewer_figures/'
os.makedirs(reviewer_folder, exist_ok = True)

# %%
epoch = 'response'
fr_threshold = 2
r2_threshold = 0.01
fr = fig2.combined_r2_data['%s_fr'%epoch]

embed = fig2.combined_r2_data['r2_embed_%s'%epoch]
marker = fig2.combined_r2_data['r2_marker_%s'%epoch]
e2e = fig2.combined_r2_data['r2_e2e_%s'%epoch]

methods = ['embedding', 'marker', 'e2e']
label_names = ['Embedding based pred.', 'Marker based pred.', 'End-to-end pred.']
color_list = ['b', 'g', 'brown']
method_data = {'embedding': embed, 'marker': marker, 'e2e': e2e}


filter = (fr > fr_threshold) & (embed > r2_threshold) #& (marker > r2_threshold) & (e2e > r2_threshold)
filter_inds = np.where(filter)[0]
ccf_labels = fig2.combined_r2_data['ccf_label']
alm_inds = np.where(fig2.combined_r2_data['is_alm'] == 1)[0]
sessions = fig2.combined_r2_data['session_name']
animals = np.array([sess[:5] for sess in sessions])
unique_animals = np.unique(animals)

animal_means = {}
animal_sems = {}

area_values_grouped_by_animal = {area: [] for area in fig2.areas}

for animal in unique_animals:
    animal_inds = np.where(animals == animal)[0]

    area_means = {method: [] for method in methods}
    area_sems = {method: [] for method in methods}
    for area in fig2.areas:
        inds = func.get_single_area_inds(area, fig2.allen_hierarchy, ccf_labels, alm_inds)
        inds = np.intersect1d(inds, filter_inds)
        inds = np.intersect1d(inds, animal_inds)
        if len(inds) != 0:
            area_values_grouped_by_animal[area].append(method_data[method][inds])
        for method in methods:
            m, sem = fig2._calc_mean_and_sem(method_data[method][inds])
            area_means[method].append(m)
            area_sems[method].append(sem)
    animal_means[animal] = area_means
    animal_sems[animal] = area_sems
# Out:
# /home/kurgyis/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/kurgyis/.local/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/kurgyis/.local/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/kurgyis/.local/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/kurgyis/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
embed_animal_means = np.array([animal_means[animal]['embedding'] for animal in unique_animals])
embed_animal_means.shape
# Out:
# (21, 5)

# %%
plt.subplots(1,1, figsize=(3.2,5))
plt.title('Single animal, embedding, response epoch explained variance')
plt.imshow(embed_animal_means, aspect='auto')
plt.colorbar(label = 'Explained variance')
plt.xticks(np.arange(len(fig2.areas)), fig2.areas, rotation = 0)
plt.yticks(np.arange(len(unique_animals)), unique_animals)
plt.ylabel('Animal')
#plt.savefig(reviewer_folder + 'single_animal_embedding_response_epoch.png', dpi=300, bbox_inches = 'tight')
# Out:
# Text(0,0.5,'Animal')

# %%
plt.subplots(1,1, figsize=(4,5)) 
for i,animal in enumerate(unique_animals):
    plt.plot(embed_animal_means[i],  'o-',lw = 0.5,color = plt.cm.gnuplot(i/len(unique_animals)),label = animal)
plt.legend()
plt.xticks(np.arange(len(fig2.areas)), fig2.areas, rotation = 0)
plt.ylabel('Explained variance')
plt.title('Single animal, embedding, response epoch explained variance')
plt.ylim(0,0.24)

#plt.savefig(reviewer_folder + 'single_animal_embedding_response_epoch_lines.png', dpi=300, bbox_inches = 'tight')
# Out:
# (0, 0.24)

# %%
groups = [row[~np.isnan(row)] for row in embed_animal_means]

# Perform ANOVA
f_stat, p_value = stats.f_oneway(*groups)

print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 1.0432965264236065
# P-value: 0.43093487022936605

# %%
def outlier_value(x, k_factor = 1.4826):
    return np.abs(x - np.median(x))/np.median(np.abs(x-np.median(x)))/k_factor


def median_abs_deviation(x):
    return np.abs(x - np.median(x))

# %%
outliers_by_area = np.array([outlier_value(embed_animal_means[:,i][~np.isnan(embed_animal_means[:,i])]) for i in range(embed_animal_means.shape[1])])
median_deviation = np.array([median_abs_deviation(embed_animal_means[:,i][~np.isnan(embed_animal_means[:,i])]) for i in range(embed_animal_means.shape[1])])
# Out:
# <ipython-input-20-5cdd13d74a76>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   outliers_by_area = np.array([outlier_value(embed_animal_means[:,i][~np.isnan(embed_animal_means[:,i])]) for i in range(embed_animal_means.shape[1])])
# <ipython-input-20-5cdd13d74a76>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   median_deviation = np.array([median_abs_deviation(embed_animal_means[:,i][~np.isnan(embed_animal_means[:,i])]) for i in range(embed_animal_means.shape[1])])

# %%
embed_animal_outliers = embed_animal_means.copy()
embed_animal_med_dev = embed_animal_means.copy()

for i in range(5):
    embed_animal_outliers[:,i][~np.isnan(embed_animal_means[:,i])] = outliers_by_area[i]
    embed_animal_med_dev[:,i][~np.isnan(embed_animal_means[:,i])] = median_deviation[i]

# %%
plt.figure(figsize=(4,3))
for i in range(5):
    plt.plot(embed_animal_outliers[:,i],'o', label = fig2.areas[i], alpha = 0.8)
    outlier_mask = embed_animal_outliers[:,i] > 3
    print(np.sum(outlier_mask))
    plt.plot(np.arange(len(unique_animals))[outlier_mask], embed_animal_outliers[:,i][outlier_mask], 'ko',markersize = 4)

plt.hlines(3, 0, len(unique_animals), color = 'k', lw = 1, label = '3x median abs. dev.')
plt.xticks(np.arange(len(unique_animals)), unique_animals, rotation = 90)
plt.ylabel('Scaled absolute median deviation')
plt.legend()

#plt.savefig(reviewer_folder + 'single_animal_embedding_response_epoch_outliers_mad.png', dpi=300, bbox_inches = 'tight')
# Out:
# 1
# 0
# 0
# 0
# 0

# %%
loo_means = embed_animal_means.copy()

for i in range(len(unique_animals)):
    animal_mask = np.ones(len(unique_animals), dtype = bool)
    animal_mask[i] = False
    means = embed_animal_means[animal_mask]
    loo_means[i] = np.array([np.mean(means[:,i][~np.isnan(means[:,i])], axis = 0) for i in range(5)])

# %%
plt.figure(figsize=(3,4.5))
plt.plot([],[],' ', label = 'Leave-one-out')
for i,animal in enumerate(unique_animals):
    plt.plot(loo_means[i],  'o-',lw = 0.5,color = plt.cm.gnuplot(i/len(unique_animals)),label = animal)
plt.legend()
plt.xticks(np.arange(len(fig2.areas)), fig2.areas, rotation = 0)
plt.ylabel('Explained variance')
plt.title('Leave-one-out explained variance')
plt.ylim(0,0.24)

#plt.savefig(reviewer_folder + 'leave_one_out_embedding_response_epoch_lines.png', dpi=300, bbox_inches = 'tight')
# Out:
# (0, 0.24)
